# %%
from IPython.display import FileLink
FileLink('.gitignore')
# Out:
# /home/jovyan/work/waymo-challenge-2025/.gitignore

# %%
# !cp .gitignore gitignore_editable.txt

# %%
cp gitignore_editable.txt .gitignore

# %%
rm gitignore_editable.txt
